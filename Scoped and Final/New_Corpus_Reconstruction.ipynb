# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

BASE_DIR = Path("/content/drive/MyDrive/Thesis")
EXP_DIR = BASE_DIR / "Structural_MorphBPE_Experiment"

DATA_DIR = EXP_DIR / "data"
MODEL_DIR = EXP_DIR / "models"
RESULT_DIR = EXP_DIR / "results"
LOG_DIR = EXP_DIR / "logs"

for directory in [DATA_DIR, MODEL_DIR, RESULT_DIR, LOG_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print("Experiment directory:", EXP_DIR)
# Out:
# Experiment directory: /content/drive/MyDrive/Thesis/Structural_MorphBPE_Experiment

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import re
import unicodedata
from collections import Counter, defaultdict

# %%
DATA_DIR = Path("/content/drive/MyDrive/Thesis/Structural_MorphBPE_Experiment")

TRAIN_FILE = DATA_DIR / "data/igbo_train_corpus.txt"
LEXICON_FILE = DATA_DIR / "data/New_Fully_Validated_IGBO_Lexicon.txt"

print("Training corpus:", TRAIN_FILE)
print("Lexicon:", LEXICON_FILE)

print("Training corpus exists:", TRAIN_FILE.exists())
print("Lexicon exists:", LEXICON_FILE.exists())
# Out:
# Training corpus: /content/drive/MyDrive/Thesis/Structural_MorphBPE_Experiment/data/igbo_train_corpus.txt
# Lexicon: /content/drive/MyDrive/Thesis/Structural_MorphBPE_Experiment/data/New_Fully_Validated_IGBO_Lexicon.txt
# Training corpus exists: True
# Lexicon exists: True

# %%
final_df = pd.read_csv(
    LEXICON_FILE,
    sep="\t",
    header=None,
    names=["word", "segmentation"],
    dtype=str,
    encoding="utf-8"
)

final_df["word"] = final_df["word"].str.strip()
final_df["segmentation"] = final_df["segmentation"].str.strip()

print("Lexicon rows:", len(final_df))
print("Unique words:", final_df["word"].nunique())
print("Missing words:", final_df["word"].isna().sum())
print("Missing segmentations:", final_df["segmentation"].isna().sum())

display(final_df.head(20))
# Out:
# Lexicon rows: 57998
# Unique words: 48059
# Missing words: 2
# Missing segmentations: 0
#                           word  \
# gọọmentị              gọọmentị
# ndị                        ndị
# onwuemeodo    onwu + eme + odo
# onye                      onye
# aafọ                      aafọ
# aakụkọ                  aakụkọ
# aba                        aba
# ababeghị     a + ba + be + ghị
# abacha                  abacha
# abagana                abagana
# abagbuola   a + ba + gbuo + la
# abaghị            a + ba + ghị
# abah                      abah
# abakaliki            abakaliki
# abakpa                  abakpa
# abakwuru     a + ba + kwu + ru
# abalị                    abalị
# abalị-asaa    abalị + - + asaa
# abalị-atọ      abalị + - + atọ
# abalị-ise      abalị + - + ise
#
#                                                  segmentation
# gọọmentị           [['g', 'ọ', 'ọ', 'm', 'e', 'n', 't', 'ị']]
# ndị                                         [['n', 'd', 'ị']]
# onwuemeodo  [['o', 'nw', 'u'], ['e', 'm', 'e'], ['o', 'd',...
# onye                                       [['o', 'ny', 'e']]
# aafọ                                   [['a', 'a', 'f', 'ọ']]
# aakụkọ                       [['a', 'a', 'k', 'ụ', 'k', 'ọ']]
# aba                                         [['a', 'b', 'a']]
# ababeghị         [['a'], ['b', 'a'], ['b', 'e'], ['gh', 'ị']]
# abacha                           [['a', 'b', 'a', 'ch', 'a']]
# abagana                 [['a', 'b', 'a', 'g', 'a', 'n', 'a']]
# abagbuola   [['a'], ['b', 'a'], ['gb', 'u', 'o'], ['l', 'a']]
# abaghị                       [['a'], ['b', 'a'], ['gh', 'ị']]
# abah                                   [['a', 'b', 'a', 'h']]
# abakaliki     [['a', 'b', 'a', 'k', 'a', 'l', 'i', 'k', 'i']]
# abakpa                           [['a', 'b', 'a', 'kp', 'a']]
# abakwuru         [['a'], ['b', 'a'], ['kw', 'u'], ['r', 'u']]
# abalị                             [['a', 'b', 'a', 'l', 'ị']]
# abalị-asaa  [['a', 'b', 'a', 'l', 'ị'], ['-'], ['a', 's', ...
# abalị-atọ   [['a', 'b', 'a', 'l', 'ị'], ['-'], ['a', 't', ...
# abalị-ise   [['a', 'b', 'a', 'l', 'ị'], ['-'], ['i', 's', ...

# %%
lexicon = (
    final_df
    .drop_duplicates(subset=["word", "segmentation"])
    .reset_index(drop=True)
)

print("Original lexicon rows:", len(final_df))
print("After exact deduplication:", len(lexicon))
print("Unique words:", lexicon["word"].nunique())
# Out:
# Original lexicon rows: 57998
# After exact deduplication: 48060
# Unique words: 48059

# %%
import pandas as pd
import ast
from pathlib import Path

LEXICON_FILE = DATA_DIR / "data/New_Fully_Validated_IGBO_Lexicon.txt"

lexicon = pd.read_csv(
    LEXICON_FILE,
    sep="\t",
    header=None,
    names=[
        "word",
        "segmentation",
        "morph_structure"
    ],
    dtype=str,
    encoding="utf-8"
)

print("Rows:", len(lexicon))
print("Columns:", lexicon.columns.tolist())

display(lexicon.head(10))
# Out:
# Rows: 57998
# Columns: ['word', 'segmentation', 'morph_structure']
#          word       segmentation  \
# 0    gọọmentị           gọọmentị
# 1         ndị                ndị
# 2  onwuemeodo   onwu + eme + odo
# 3        onye               onye
# 4        aafọ               aafọ
# 5      aakụkọ             aakụkọ
# 6         aba                aba
# 7    ababeghị  a + ba + be + ghị
# 8      abacha             abacha
# 9     abagana            abagana
#
#                                      morph_structure
# 0         [['g', 'ọ', 'ọ', 'm', 'e', 'n', 't', 'ị']]
# 1                                  [['n', 'd', 'ị']]
# 2  [['o', 'nw', 'u'], ['e', 'm', 'e'], ['o', 'd',...
# 3                                 [['o', 'ny', 'e']]
# 4                             [['a', 'a', 'f', 'ọ']]
# 5                   [['a', 'a', 'k', 'ụ', 'k', 'ọ']]
# 6                                  [['a', 'b', 'a']]
# 7       [['a'], ['b', 'a'], ['b', 'e'], ['gh', 'ị']]
# 8                       [['a', 'b', 'a', 'ch', 'a']]
# 9              [['a', 'b', 'a', 'g', 'a', 'n', 'a']]

# %%
def parse_morph_structure(value):
    if pd.isna(value):
        return None

    try:
        structure = ast.literal_eval(value)

        if isinstance(structure, list):
            return structure

        return None

    except (ValueError, SyntaxError):
        return None

# %%
lexicon["morph_structure"] = (
    lexicon["morph_structure"]
    .apply(parse_morph_structure)
)

# %%
print(
    "Valid morphological structures:",
    lexicon["morph_structure"].notna().sum()
)

print(
    "Missing morphological structures:",
    lexicon["morph_structure"].isna().sum()
)
# Out:
# Valid morphological structures: 57998
# Missing morphological structures: 0

# %%
display(
    lexicon[
        ["word", "segmentation", "morph_structure"]
    ].head(20)
)
# Out:
#           word        segmentation                       morph_structure
# 0     gọọmentị            gọọmentị            [[g, ọ, ọ, m, e, n, t, ị]]
# 1          ndị                 ndị                           [[n, d, ị]]
# 2   onwuemeodo    onwu + eme + odo    [[o, nw, u], [e, m, e], [o, d, o]]
# 3         onye                onye                          [[o, ny, e]]
# 4         aafọ                aafọ                        [[a, a, f, ọ]]
# 5       aakụkọ              aakụkọ                  [[a, a, k, ụ, k, ọ]]
# 6          aba                 aba                           [[a, b, a]]
# 7     ababeghị   a + ba + be + ghị        [[a], [b, a], [b, e], [gh, ị]]
# 8       abacha              abacha                    [[a, b, a, ch, a]]
# 9      abagana             abagana               [[a, b, a, g, a, n, a]]
# 10   abagbuola  a + ba + gbuo + la     [[a], [b, a], [gb, u, o], [l, a]]
# 11      abaghị        a + ba + ghị                [[a], [b, a], [gh, ị]]
# 12        abah                abah                        [[a, b, a, h]]
# 13   abakaliki           abakaliki         [[a, b, a, k, a, l, i, k, i]]
# 14      abakpa              abakpa                    [[a, b, a, kp, a]]
# 15    abakwuru   a + ba + kwu + ru        [[a], [b, a], [kw, u], [r, u]]
# 16       abalị               abalị                     [[a, b, a, l, ị]]
# 17  abalị-asaa    abalị + - + asaa  [[a, b, a, l, ị], [-], [a, s, a, a]]
# 18   abalị-atọ     abalị + - + atọ     [[a, b, a, l, ị], [-], [a, t, ọ]]
# 19   abalị-ise     abalị + - + ise     [[a, b, a, l, ị], [-], [i, s, e]]

# %%
for i in range(10):
    print(
        repr(lexicon.loc[i, "word"]),
        "→",
        repr(lexicon.loc[i, "morph_structure"])
    )
# Out:
# 'gọọmentị' → [['g', 'ọ', 'ọ', 'm', 'e', 'n', 't', 'ị']]
# 'ndị' → [['n', 'd', 'ị']]
# 'onwuemeodo' → [['o', 'nw', 'u'], ['e', 'm', 'e'], ['o', 'd', 'o']]
# 'onye' → [['o', 'ny', 'e']]
# 'aafọ' → [['a', 'a', 'f', 'ọ']]
# 'aakụkọ' → [['a', 'a', 'k', 'ụ', 'k', 'ọ']]
# 'aba' → [['a', 'b', 'a']]
# 'ababeghị' → [['a'], ['b', 'a'], ['b', 'e'], ['gh', 'ị']]
# 'abacha' → [['a', 'b', 'a', 'ch', 'a']]
# 'abagana' → [['a', 'b', 'a', 'g', 'a', 'n', 'a']]

# %%
def flatten_morph_structure(structure):
    if not structure:
        return ""

    return "".join(
        "".join(unit)
        for unit in structure
    )

# %%
lexicon["reconstructed_word"] = (
    lexicon["morph_structure"]
    .apply(flatten_morph_structure)
)

# %%
import pandas as pd
import ast
from pathlib import Path

# Directory already defined
# DATA_DIR = Path(...)

LEXICON_FILE = DATA_DIR / "data/New_Fully_Validated_IGBO_Lexicon.txt"

lexicon = pd.read_csv(
    LEXICON_FILE,
    sep="\t",
    header=None,
    names=["word", "segmentation", "morph_structure"],
    dtype=str,
    encoding="utf-8"
)

print("Lexicon rows:", len(lexicon))
print("Columns:", lexicon.columns.tolist())

display(lexicon.head())
# Out:
# Lexicon rows: 57998
# Columns: ['word', 'segmentation', 'morph_structure']
#          word      segmentation  \
# 0    gọọmentị          gọọmentị
# 1         ndị               ndị
# 2  onwuemeodo  onwu + eme + odo
# 3        onye              onye
# 4        aafọ              aafọ
#
#                                      morph_structure
# 0         [['g', 'ọ', 'ọ', 'm', 'e', 'n', 't', 'ị']]
# 1                                  [['n', 'd', 'ị']]
# 2  [['o', 'nw', 'u'], ['e', 'm', 'e'], ['o', 'd',...
# 3                                 [['o', 'ny', 'e']]
# 4                             [['a', 'a', 'f', 'ọ']]

# %%
lexicon["morph_structure"] = lexicon["morph_structure"].apply(
    lambda x: ast.literal_eval(x) if pd.notna(x) else None
)

# %%
print(
    "Valid morphological structures:",
    lexicon["morph_structure"].notna().sum()
)

print(
    "Missing morphological structures:",
    lexicon["morph_structure"].isna().sum()
)
# Out:
# Valid morphological structures: 57998
# Missing morphological structures: 0

# %%
morph_lookup = dict(
    zip(
        lexicon["word"],
        lexicon["morph_structure"]
    )
)

print("Morphology lookup entries:", len(morph_lookup))
# Out:
# Morphology lookup entries: 57949

# %%
for word in ["gọọmentị", "ndị", "onwuemeodo", "ababeghị"]:
    print(word, "→", morph_lookup.get(word))
# Out:
# gọọmentị → [['g', 'ọ', 'ọ', 'm', 'e', 'n', 't', 'ị']]
# ndị → [['n', 'd', 'ị']]
# onwuemeodo → [['o', 'nw', 'u'], ['e', 'm', 'e'], ['o', 'd', 'o']]
# ababeghị → [['a'], ['b', 'a'], ['b', 'e'], ['gh', 'ị']]

# %%
TRAIN_FILE = DATA_DIR / "data/igbo_train_corpus.txt"

with open(
    TRAIN_FILE,
    "r",
    encoding="utf-8"
) as f:
    train_lines = f.readlines()

print("Number of lines:", len(train_lines))
print("First line:")
print(repr(train_lines[0]))
# Out:
# Number of lines: 35078
# First line:
# 'Sowore Revolution: Ka ekwe si akụ maka ngagharịiwe e ji maka ya nwụchie Sowore BBC Igbo kwụ chịm iwetara gị ihe na-aga ka a na-ekwu okwu ngagharịiwe na mpaghara dị iche iche na Naịjirịa.\n'

# %%
train_tokens = []

for line in train_lines:
    train_tokens.extend(line.split())

print("Total corpus tokens:", len(train_tokens))
print("Unique corpus tokens:", len(set(train_tokens)))
# Out:
# Total corpus tokens: 833843
# Unique corpus tokens: 54493

# %%
scoped_corpus = []

covered = 0
uncovered = 0

for token in train_tokens:

    structure = morph_lookup.get(token)

    if structure is not None:
        scoped_corpus.append(structure)
        covered += 1

    else:
        scoped_corpus.append([
            list(token)
        ])
        uncovered += 1

print("Covered occurrences:", covered)
print("Uncovered occurrences:", uncovered)

print(
    f"Coverage: {covered / len(train_tokens):.4%}"
)
# Out:
# Covered occurrences: 833735
# Uncovered occurrences: 108
# Coverage: 99.9870%

# %%
for i in range(30):
    print(
        train_tokens[i],
        "→",
        scoped_corpus[i]
    )
# Out:
# Sowore → [['S', 'o', 'w', 'o', 'r', 'e']]
# Revolution: → [['R', 'e', 'v', 'o', 'l', 'u', 't', 'i', 'o', 'n', ' ', ':']]
# Ka → [['k', 'a']]
# ekwe → [['e', 'kw', 'e']]
# si → [['s', 'i']]
# akụ → [['a', 'k', 'ụ']]
# maka → [['m', 'a', 'k', 'a']]
# ngagharịiwe → [['n', 'g', 'a', 'gh', 'a', 'r', 'ị'], ['i', 'w', 'e']]
# e → [['e']]
# ji → [['j', 'i']]
# maka → [['m', 'a', 'k', 'a']]
# ya → [['y', 'a']]
# nwụchie → [['nw', 'ụ'], ['ch', 'i'], ['e']]
# Sowore → [['S', 'o', 'w', 'o', 'r', 'e']]
# BBC → [['B', 'B', 'C']]
# Igbo → [['i', 'gb', 'o']]
# kwụ → [['kw', 'ụ']]
# chịm → [['ch', 'ị'], ['m']]
# iwetara → [['i'], ['w', 'e'], ['t', 'a'], ['r', 'a']]
# gị → [['g', 'ị']]
# ihe → [['i', 'h', 'e']]
# na-aga → [['n', 'a', '-', 'a'], ['g', 'a']]
# ka → [['k', 'a']]
# a → [['a']]
# na-ekwu → [['n', 'a', '-', 'e'], ['kw', 'u']]
# okwu → [['o', 'kw', 'u']]
# ngagharịiwe → [['n', 'g', 'a', 'gh', 'a', 'r', 'ị'], ['i', 'w', 'e']]
# na → [['n', 'a']]
# mpaghara → [['m', 'p', 'a', 'gh', 'a', 'r', 'a']]
# dị → [['d', 'ị']]

# %%
import json

SCOPED_CORPUS_FILE = DATA_DIR / "New_igbo_morph_scoped_corpus.json"

with open(
    SCOPED_CORPUS_FILE,
    "w",
    encoding="utf-8"
) as f:
    json.dump(
        scoped_corpus,
        f,
        ensure_ascii=False
    )

print(
    "Saved:",
    SCOPED_CORPUS_FILE
)
# Out:
# Saved: /content/drive/MyDrive/Thesis/Structural_MorphBPE_Experiment/New_igbo_morph_scoped_corpus.json

# %%
LOOKUP_FILE = DATA_DIR / "data/New_igbo_morphology_lookup.json"

with open(
    LOOKUP_FILE,
    "w",
    encoding="utf-8"
) as f:
    json.dump(
        morph_lookup,
        f,
        ensure_ascii=False
    )

print(
    "Saved:",
    LOOKUP_FILE
)
# Out:
# Saved: /content/drive/MyDrive/Thesis/Structural_MorphBPE_Experiment/data/New_igbo_morphology_lookup.json
